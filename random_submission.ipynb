# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('/kaggle/input/home-credit-credit-risk-model-stability/csv_files/train/train_base.csv')

# %%
train['target'].value_counts(normalize=True)
# Out:
# target
# 0    0.968563
# 1    0.031437
# Name: proportion, dtype: float64

# %%
train['target'].hist()
# Out:
# <Axes: >

# %%
test = pd.read_csv('/kaggle/input/home-credit-credit-risk-model-stability/csv_files/test/test_base.csv')

# %%
submission = pd.DataFrame({
    'case_id': test['case_id'],
#     'score': np.random.choice([0, 1], size=len(test['case_id']), p=[0.968563, 0.031437]),
    'score': np.random.binomial(n=1, p=0.031437, size=len(test['case_id'])),
})

# %%
submission
# Out:
#    case_id  score
# 0    57543      0
# 1    57549      0
# 2    57551      0
# 3    57552      0
# 4    57569      0
# 5    57630      0
# 6    57631      1
# 7    57632      0
# 8    57633      0
# 9    57634      0

# %%
submission.to_csv('submission.csv')
